# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenjiro1/Formacao_IA/blob/main/Projetos/Tecnicas_avan%C3%A7adas_para_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %%
#Codigo para utilizarmos fonte do git hub
# !git clone https://github.com/kenjiro1/Formacao_IA.git
# Out:
# Cloning into 'Formacao_IA'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 119 (delta 37), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.03 MiB | 3.83 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
import sys
sys.path.append('/content/Formacao_IA/Recursos')
from hopkins import  *
from metric import  *
from visual_assessment_of_tendency import *

# %% [markdown]
# #Comecamos o codigo aqui

# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


import warnings

warnings.filterwarnings("ignore", category = FutureWarning)

# %%
iris = datasets.load_iris()

clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150,4))

# %%
print(clust2)
# Out:
# [[ 0.15116401 -0.948762   -0.85245839  0.3089481 ]
#  [ 1.38680676  1.49171197 -1.14157214 -1.05353073]
#  [ 0.98853974  1.1188334   1.71605853  0.25948753]
#  [ 1.43409683 -0.30839906 -0.86380727  1.80193987]
#  [-0.74994574 -0.99524463  0.25073608 -1.13377249]
#  [ 0.31924261 -1.15337215 -1.11928235  0.63271641]
#  [ 0.1346754   1.63727733 -0.18629687 -1.30548204]
#  [-0.57075802 -1.70043134 -0.21709384  0.66051866]
#  [ 1.47235709 -0.41074771  0.26034999 -0.16053605]
#  [-1.82244694 -1.73122903 -1.44233059  1.30381877]
#  [-1.62627144 -0.40308812  1.22116638 -1.3929158 ]
#  [-0.27925595 -0.81310997 -0.18297903  0.13997486]
#  [-0.78041016 -1.72857353  0.83753309  1.54938222]
#  [ 1.64354517 -1.43550068 -0.14636725 -0.17904585]
#  [ 0.12294035 -1.66012814  1.35051834 -1.28181226]
#  [ 0.4073146  -1.384306    0.16864096 -1.25545129]
#  [ 0.08930627  0.85886266 -1.2605996  -0.30373287]
#  [-0.81960981 -0.58926554  0.88164965 -0.89534455]
# ...

# %%
#Usaremos o grafico de elbow para cluster 1
inertia = []
for i in range(1,8):
  kmeans = KMeans(n_clusters= i, n_init='auto')
  kmeans.fit(clust1)
  inertia.append(kmeans.inertia_)

plt.plot(range(1,8), inertia)
plt.title('elbow')
# Out:
# Text(0.5, 1.0, 'elbow')

# %%
#Usaremos o grafico de elbow cluster 2
inertia = []
for i in range(1,10):
  kmeans = KMeans(n_clusters= i, n_init='auto')
  kmeans.fit(clust2)
  inertia.append(kmeans.inertia_)

plt.plot(range(1,10), inertia)
plt.title('elbow')
# Out:
# Text(0.5, 1.0, 'elbow')

# %%
hopkins(clust1,150)
# Out:
# np.float64(0.18296200222385017)

# %%
hopkins(clust2,150) # muito proximo de 1, significa que nao tem um padrao de cluster nos dados
# Out:
# np.float64(0.48624741866033533)

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
#Metrica que informa o numero ideal de clusters
#m = assess_tendency_by_metric(clust1, "silhouette", 5)
#m = assess_tendency_by_metric(clust1, "davies_bouldin", 5)
m = assess_tendency_by_metric(clust2, "calinski_harabasz", 5)
print(m)
# Out:
# (np.int64(2), array([38.99111069, 37.52514182, 34.08260231, 38.26739897]))

# %%
m = assess_tendency_by_mean_metric_score(clust1,5)
print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2,5)
print(m)
# Out:
# 4.0
